# %%
print("Hello, AI Master Journey!")
# Out:
# Hello, AI Master Journey!

# %%
import sys
print(sys.version)
# Out:
# 3.12.7 (tags/v3.12.7:0b05ead, Oct  1 2024, 03:06:41) [MSC v.1941 64 bit (AMD64)]

# %%
x = 10
y = 20
print(x + y)
# Out:
# 30
